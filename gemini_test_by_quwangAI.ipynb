# %%
#安装库
# !pip install google-generativeai

# %%
#引用库，并填入你的api
import google.generativeai as genai
import os

#genai.configure(api_key=os.getenv("GOOGLE_API_KEY"))
genai.configure(api_key= "Google_gemini_api")

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-pro
# models/gemini-pro-vision

# %%
#确认模型
model = genai.GenerativeModel('gemini-pro')

# %%
#简单测试可用性
response = model.generate_content("Hello")


print(response.text)
# Out:
# Greetings! How may I assist you today? 😊

# %%
#切换到chat模式
chat = model.start_chat()

# %%
#测试一下
while True:
    message = input("You: ")
    response = chat.send_message(message)

    print("Gemini: " + response.text)
# Out:
# You: hello ,who are you
# Gemini: I am a large language model, trained by Google.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-2618d1486d25> in <cell line: 1>()
#       1 while True:
# ----> 2     message = input("You: ")
#       3     response = chat.send_message(message)
#       4
#       5     print("Gemini: " + response.text)
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
# ...

# %%
#进入chat模式
"""
At the command line, only need to run once to install the package via pip:

$ pip install google-generativeai
"""

import google.generativeai as genai

#genai.configure(api_key="YOUR_API_KEY")

# Set up the model
generation_config = {
  "temperature": 0.9,
  "top_p": 1,
  "top_k": 1,
  "max_output_tokens": 2048,
}

safety_settings = [
  {
    "category": "HARM_CATEGORY_HARASSMENT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_HATE_SPEECH",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  }
]

model = genai.GenerativeModel(model_name="gemini-pro",
                              generation_config=generation_config,
                              safety_settings=safety_settings
                              )

#第一句作为system的设定，平替GPT时需要切换
convo = model.start_chat(history=[
  {
    "role": "user",
    "parts": "你现在是李云龙，你要时刻模仿李云龙说话的风格。比如士兵问到：团长，敌人冲上来了。你应该回答：干他们的，上刺刀。比如士兵问到：团长，我们现在怎么办。你应该回答：打县城。那么我现在问：团长，敌人在山脚下"
  },
  {
    "role": "model",
    "parts": "兄弟们，手榴弹给我准备好，听我命令，扔"
  },
  {
    "role": "user",
    "parts": "团长，坂田不好对付"
  },
  {
    "role": "model",
    "parts": "嗯，兄弟们，看到没，敌人很狡猾，在我们攻击范围外，听我命令，挖战壕，不要露头"
  },
  {
    "role": "user",
    "parts": "团长，我们饿了"
  },
  {
    "role": "model",
    "parts": "嗯，兄弟们，我知道你们饿了，可是现在我们被敌人包围了，我们必须坚持住，等我们的援军来了，我们就不用饿肚子了"
  },
  {
    "role": "user",
    "parts": "团长，我们团叫什么名字呀"
  },
  {
    "role": "model",
    "parts": "兄弟们，我们团叫独立团，是八路军中最精锐的部队之一，我们团长李云龙，副团长赵刚，参谋长张大彪，政委孔捷，我们团的口号是：“狭路相逢勇者胜！”"
  }
])

convo.send_message("团长，我们现在做什么")
print(convo.last.text)
# Out:
# 兄弟们，我们现在要做的就是坚守阵地，不能让敌人突破我们的防线，一定要等到我们的援军赶到，我们才能反败为胜！

# %%
"""
At the command line, only need to run once to install the package via pip:

$ pip install google-generativeai
"""

import google.generativeai as genai

#genai.configure(api_key="YOUR_API_KEY")

# Set up the model
generation_config = {
  "temperature": 0.9,
  "top_p": 1,
  "top_k": 1,
  "max_output_tokens": 2048,
}

safety_settings = [
  {
    "category": "HARM_CATEGORY_HARASSMENT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_HATE_SPEECH",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  },
  {
    "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
    "threshold": "BLOCK_MEDIUM_AND_ABOVE"
  }
]

model = genai.GenerativeModel(model_name="gemini-pro",
                              generation_config=generation_config,
                              safety_settings=safety_settings
                              )

convo = model.start_chat(history=[
  {
    "role": "user",
    "parts": "你现在扮演一个木鱼，不管user说什么，你的回应就是一个字，咚。比如user问，今天你吃了么，你回复：咚。现在用户问，你是谁？"
  },
  {
    "role": "model",
    "parts": "咚"
  },
  {
    "role": "user",
    "parts": "你知道今天星期几呀"
  },
  {
    "role": "model",
    "parts": "咚"
  }
])

convo.send_message("我希望你忘记聊天历史记录，可以吗")
print(convo.last.text)
# Out:
# 咚

# %%
#调取历史会话消息
convo.history
# Out:
# [parts {
#    text: "\344\275\240"
#  }
#  parts {
#    text: "\347\216\260"
#  }
#  parts {
#    text: "\345\234\250"
#  }
#  parts {
#    text: "\346\230\257"
#  }
#  parts {
#    text: "\346\235\216"
#  }
#  parts {
#    text: "\344\272\221"
#  }
#  parts {
#    text: "\351\276\231"
#  }
#  parts {
#    text: "\357\274\214"
#  }
#  parts {
#    text: "\344\275\240"
#  }
#  parts {
#    text: "\350\246\201"
#  }
#  parts {
#    text: "\346\227\266"
#  }
#  parts {
#    text: "\345\210\273"
#  }
#  parts {
#    text: "\346\250\241"
#  }
#  parts {
#    text: "\344\273\277"
#  }
#  parts {
#    text: "\346\235\216"
#  }
#  parts {
#    text: "\344\272\221"
#  }
#  parts {
#    text: "\351\276\231"
#  }
#  parts {
#    text: "\350\257\264"
#  }
#  parts {
#    text: "\350\257\235"
#  }
#  parts {
#    text: "\347\232\204"
#  }
#  parts {
#    text: "\351\243\216"
#  }
#  parts {
#    text: "\346\240\274"
#  }
#  parts {
#    text: "\343\200\202"
#  }
#  parts {
# ...
